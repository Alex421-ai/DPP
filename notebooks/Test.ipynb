# %%
a= 2
b= 3

print(a+b+a)
# Out:
# 7

# %%
import matplotlib

# %%
import os

# %%
os

import pandas as pd

df = pd.read_csv(fdata\raw\heartdisease\Heart_Disease_Prediction.csv)
# Out:
#   Cell In[15], line 5
#     df = pd.read_csv(fdata\raw\heartdisease\Heart_Disease_Prediction.csv)
#                            ^
# SyntaxError: unexpected character after line continuation character

# %%
import pandas as pd

df = pd.read_csv("data/raw/heartdisease/Heart_Disease_Prediction.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv("data/raw/heartdisease/Heart_Disease_Prediction.csv")
#       4 df.head()
#
# ...

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\Major\\Desktop\\Weiterbildung Daten Anlayst\\DPP\\notebooks'

# %%
import pandas as pd

df = pd.read_csv("../data/raw/heartdisease/Heart_Disease_Prediction.csv")
df.head()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        3         3      Presence
# 1                        0         7       Absence
# ...
